# %% [markdown]
# # Answer for question 1

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\user\anaconda3\lib\site-packages (3.141.0)
# Requirement already satisfied: urllib3 in c:\users\user\anaconda3\lib\site-packages (from selenium) (1.25.11)

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
driver = webdriver.Chrome(r"C:\Users\hh472\Desktop\fliproobo\chromedriver.exe")

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
#finding element by id
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="460beaad-8568-477d-aec8-8ea3c5526d48")>

# %%
search_job.send_keys("Data Analyst")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Bangalore")

# %%
search_btn = driver.find_element_by_class_name('btn')
search_btn.click()

# %%
#extracting all the tags having job titles
titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']") #element's' gives us all the elements
titles_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="04ec4345-d6fd-4160-a25c-a4bf14d9ae52")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6a59802e-f587-4d47-bb77-cfd8feb1d2e6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="267d2101-4905-4f5c-8072-ae40a967e858")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9dee9b04-e7fb-4634-895d-6cd70a648dc3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5d9dbac5-7bf7-42bb-b0d0-811da0d4f911")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fcb94ad1-e997-44ac-9997-5eec3f5efc4b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b743a08d-24e7-4265-b1da-bf3aec82f01e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2e209e7b-6783-4e88-9d5f-6bca90892885")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="8edbddc4-9a82-48ff-ac6c-72602d6ab3cb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5de4cf3e-2185-4aa4-ac7e-33d031cb276d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f9760a1f-2954-4bd7-b08f-5561e0d66c4c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="7ab0ee07-be67-43cd-ac3c-b911b4110587")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="57fd08d2-bc2a-4be1-ae4e-8722d1ed0958")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="31270773-d49a-4ba1-b075-4ba6bbeaf17f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d63da98a-7c97-4924-a3d6-f451712127aa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="982775e1-a3c4-4779-a520-6d9e67493565")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2edd2a60-023d-496c-9c6b-0def27f0ce97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="50d8a6a2-d42f-4afe-b20e-703b6dced618")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="73befc9c-be17-459b-aa66-3b824311e137")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="761d5741-0f3e-45d6-8991-2be84b862bd4")>]

# %%
job_titles=[]
for i in titles_tags:
    job_titles.append(i.text.replace('\n',''))
job_titles
# Out:
# ['Business Data Analyst',
#  'Business Data Analyst',
#  'Data Analyst',
#  'Data Analyst/Business Analyst-Gurgaon/Bangalore/Mumbai (only Females)',
#  'Data Analyst',
#  'Data Analyst',
#  'Systems and Data Analyst, Safety and Provisioning',
#  'Data Analyst',
#  'Senior Data Analyst - SQL/Tableau/Redshift',
#  'Lead Data Analyst',
#  'Data Analyst _ 2-5 Years _ Bangalore',
#  'Data Analyst',
#  'Data Analyst',
#  'Lead Data Analyst',
#  'Data Analyst , Product',
#  'Data Annotator | Data Entry | Work From Home | Data analyst | Data QC',
#  'Senior Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst - Work from Home',
#  'Data Analyst']

# %%
#extracting all the company names
companies_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
companies_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3e7674fa-351b-47a0-8aaf-b98b32f57876")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b3baaf4c-56ab-4b10-8a94-bac4c0ff5969")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="77dbd2be-6fd4-40a1-9edc-9cb574fdeb70")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="298dcc95-c1de-48af-9761-32818e5cfdac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2c6b6e7e-98e8-43e8-986c-1a5ea874a9db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="0dde19d2-14ac-438f-8d38-c093179f59ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="dd31c5dd-f6f6-4412-8c19-692aa9d350a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b1ca7d30-7905-4046-9525-d1e33266f84b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="cfcbe734-c1dc-410d-b705-12353be0a1a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fcdf0f54-5d80-4d0b-84f0-1efdb581a03b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="bcd2dd0e-be9a-4d97-898d-e0bdebd5483a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5d9b0f91-1125-44f4-b85a-d366c1e5e3ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a29f0954-56c2-4a52-8496-3660d4c39589")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="adf66337-07f4-4817-a84d-0bdc75906c81")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="7297baf5-dc6c-4ac7-b66b-cc702113d058")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="8cac0af1-d77b-4159-9f40-7ea2269c5d75")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2c29e858-ef10-43d0-a63c-aa257a9a5115")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a50ee6eb-37b5-4da0-9fc8-8bb4c9e7303f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3f62de5a-3d27-4b54-a077-7bac6a670dcb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5cd43e32-718f-412e-9daa-55392ca47252")>]

# %%
company_names=[]
for i in companies_tags:
    company_names.append(i.text)
company_names
# Out:
# ['Trigent Software',
#  'Trigent Software',
#  'Chaitanya India Fin Credit P',
#  'India Medtronic Pvt. Ltd,.',
#  'WEIWO Communication Pvt. Ltd.',
#  'GCC SERVICES INDIA PRIVATE LIMITED',
#  'AECOM India Private Limited',
#  'Enzen Global Solutions Pvt. Ltd',
#  'Pronto Consulting Services',
#  'Bidgely Technologies Private Limited',
#  'Teamware Solutions ( A division of Quantum Leap Co nsulting Private LTD).',
#  'vLogix Technologies Pvt. Ltd.,',
#  'Rubixe (A brand under Think Ahead Innovations Pvt Ltd)',
#  'MediaMath',
#  'MediaMath',
#  'saarthi.ai',
#  'Publicis Groupe',
#  'Publicis Groupe',
#  'POWER STORES E COMMERCE PRIVATE LIMITED',
#  'Innovsource Services Private Limited']

# %%
#extracting years of experience
experience_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']//span") #span is used at the end to extract only the years
experience_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4eaf8ae5-9768-4c82-9c87-965dbe3759b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6a2d42a9-aac3-4133-ac1a-db83cfa12e22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fd907fee-bd09-4b23-b7ec-e055361a06b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="8b22c43a-00b0-4351-9a3a-dea91b283d9e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="0d904998-1926-497a-8382-71b433afbd43")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="1e6ab9c4-f163-4892-b3f6-021724d1fd4c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="19220702-e2fa-484e-83ce-40cd1d0ac956")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fedbe915-b1c5-4250-a74e-f7eb91a09bf8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="10e75134-e090-463d-86a6-b42144478841")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d26693ba-cc3e-4ae9-adc4-3a063a7ed7ce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d8b44a4d-5c16-4c54-a329-420c50c2eb38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d52c70a1-48bb-4275-8dfd-6a34934edbf2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6c27f4d6-e50b-4638-84ac-8c53cda5578d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d86adc18-69bb-4b21-bf07-252bff90b493")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="7e21c6ea-e91c-428f-a40c-b8f967acd1e6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ba902af8-9fc3-4818-9643-5f6dcf410e94")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="82be2b5d-c1e8-4665-976c-2bc32d039d54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="51584b48-4fa5-47be-a7ce-a702e1e06c22")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="14564c45-d79f-4f15-8563-5f06b9127bea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="007b4ca6-40c5-495c-bb0a-cacc4664a3d8")>]

# %%
experience_list=[]
for i in experience_tags:
    experience_list.append(i.text)
experience_list
# Out:
# ['3-5 Yrs',
#  '3-5 Yrs',
#  '0-0 Yrs',
#  '1-4 Yrs',
#  '4-8 Yrs',
#  '5-9 Yrs',
#  '3-5 Yrs',
#  '6-8 Yrs',
#  '6-10 Yrs',
#  '5-10 Yrs',
#  '2-5 Yrs',
#  '8-12 Yrs',
#  '2-6 Yrs',
#  '8-13 Yrs',
#  '4-9 Yrs',
#  '0-2 Yrs',
#  '1-3 Yrs',
#  '1-5 Yrs',
#  '2-5 Yrs',
#  '1-6 Yrs']

# %%
#extracting locations
location_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']//span[1]") #span is used at the end to extract only the 1st index which is location
location_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ae33c72b-55f2-42f0-b8da-1ca134c624fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3918ef20-c37a-496f-a693-cf0c47963735")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e3545e65-a249-4619-9020-7c51f3246d17")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6ee9b95b-633c-475f-9d26-a90f3c5e70a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d93c1649-521d-4910-b0a5-37d0726c1e83")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e28347bf-f3d7-40ed-8142-d5eb973e722b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="81a52c28-3883-4e7a-ab61-7afd36c1b713")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a12f6d04-fd30-4ee7-9ea5-cd54d92689fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d225df4e-d0ec-455d-a01c-f2dc0a0181d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6c16c06b-7b8d-4e0f-b719-b0b7e8b4c68f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4ff689ca-3249-4f16-894a-ec71a959f41a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="17e07ad8-1227-45b5-9c8e-46f13a09f263")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d3125bd8-27f9-4710-9182-0af9b8c33608")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b173c235-1cc1-4cf0-81a5-cac4ce6477b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="dd41dfe3-60e9-44c4-b1d3-49d5bfdaec10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f2b3aa73-e5ec-444f-8c39-d919b0c78e86")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="05b7758a-06d6-4476-bde3-7317e1f2ca3b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="feee9d25-a429-4753-9b90-c6b4768404bd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="01bd4f59-4e3d-4d56-b0f0-7d3ff13eadc1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2e5254cd-debf-468d-81d9-a5ac5b8b3053")>]

# %%
locations_names=[]
for i in location_tags:
    locations_names.append(i.text)
locations_names
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Bangalore/Bengaluru(Ulsoor)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Noida, Mumbai, Indore, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'United States (USA), Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Pune, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Bangalore/Bengaluru']

# %%
print(len(job_titles),len(company_names),len(experience_list),len(locations_names))
# Out:
# 20 20 20 20

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_titles
jobs['company']=company_names
jobs['experience']=experience_list
jobs['location']=locations_names

# %%
jobs
# Out:
#                                                 title  \
# 0                               Business Data Analyst
# 1                               Business Data Analyst
# 2                                        Data Analyst
# 3   Data Analyst/Business Analyst-Gurgaon/Bangalor...
# 4                                        Data Analyst
# 5                                        Data Analyst
# 6   Systems and Data Analyst, Safety and Provisioning
# 7                                        Data Analyst
# 8          Senior Data Analyst - SQL/Tableau/Redshift
# 9                                   Lead Data Analyst
# 10               Data Analyst _ 2-5 Years _ Bangalore
# 11                                       Data Analyst
# 12                                       Data Analyst
# 13                                  Lead Data Analyst
# 14                             Data Analyst , Product
# 15  Data Annotator | Data Entry | Work From Home |...
# 16                                Senior Data Analyst
# 17                                Senior Data Analyst
# 18                      Data Analyst - Work from Home
# 19                                       Data Analyst
#
#                                               company experience  \
# 0                                    Trigent Software    3-5 Yrs
# 1                                    Trigent Software    3-5 Yrs
# 3  Gurgaon/Gurugram, Bangalore/Bengaluru, Mumbai ...
# 4                        Bangalore/Bengaluru(Ulsoor)
# 5                                Bangalore/Bengaluru
# 6                                Bangalore/Bengaluru
# 7                                Bangalore/Bengaluru
# 8  Noida, Mumbai, Indore, Hyderabad/Secunderabad,...
# 9           United States (USA), Bangalore/Bengaluru

# %% [markdown]
# # Answer for question 2

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a7f27c3c-4de3-4a8d-8da6-11f28d63387c")>

# %%
search_job.send_keys("Data scientist")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys("Bangalore")

# %%
search_btn = driver.find_element_by_class_name('btn')
search_btn.click()

# %%
#extracting all the tags having job titles
titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']") #element's' gives us all the elements
titles_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="417b9fe5-eb3c-4431-8545-c31c4fe882c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b5c527a4-d0e6-4d63-923b-0136d74d4510")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="414333ad-d2ce-4ecb-a5cc-1e2a8ee57f69")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="847c0a58-eeb5-4dd7-a425-a0cd6ca2c992")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5a6d4d61-4970-43ad-b4d5-149e96e6367b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3cb3711f-2a32-4767-a00c-22961770d610")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c8878af3-f8e2-4ad0-8db8-262e5f3f8a06")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="7f9cdf5c-ec1d-4433-a87c-1d06c1067178")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4514562b-e744-4779-9ec2-895745beabf2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f75e36cb-71b1-45db-b3fc-3213eeb5c891")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="532bd664-926f-423f-9cc3-ab6e1992bf6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4f1ac1d3-0b72-4f09-abaf-150fc8b5ea99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="01ab05d1-6328-409a-b914-fbf9c2106df3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="13a6eda8-24d7-43e5-b738-65f9cd8ffed3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4ad1ad95-0184-442e-bb3f-4e9df26b47b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a7e79632-8b79-4266-af84-2afeba4aa06c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ea85db9c-a65b-4fb7-b7bc-22c75d93afd6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b8bba7c9-d229-4ee5-92c5-da773b3e39c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="014074bb-673c-41af-90a6-958afee09a8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6f77283f-1eef-4bf8-a70d-d89f8ddd506c")>]

# %%
job_titles=[]
for i in titles_tags:
    job_titles.append(i.text.replace('\n',''))
job_titles
# Out:
# ['Senior Data Scientist',
#  'Lead Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'DATA SCIENTIST',
#  'Data Scientist - Permanent Role',
#  'Data Engineers , Data Scientist and SAP',
#  'Python - Data Scientist',
#  'Western Digital Data Scientist 3',
#  'Western Digital Data Scientist',
#  'Data Scientist 4',
#  'Data Scientist /Sr.Data Scientist',
#  'Senior Software Engineer - Data Scientist',
#  'Senior Associate - Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Senior Data Scientist',
#  'Sr Data Scientist',
#  'Sr . Data Scientist']

# %%
#extracting all the company names
companies_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
companies_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="831b2b56-89c3-409d-b21e-7eb6bc76c0e3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="409d0165-b4ad-4cdb-8853-eddd8f8ce5d3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="87bc9487-4faf-4264-b4cf-8d3bf5dc00bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9da5ba9f-30fa-4542-bcad-75990fa2ff3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a6b03037-cbc1-4cb4-a3a1-183cb0c6c07a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="736d8a6b-1d1f-4f72-b01c-9957b5d52482")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c1ebea9f-a466-4e2c-b1ee-8896ab3d9c4a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5bfd99b6-4972-46ef-a585-5bc7e69180ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a15c5d0b-8372-4acd-9d8a-e42f83a01451")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="17f8a4ce-6d75-436c-baca-5d7d8ea15c3c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c07fca78-4a2a-4e88-86cc-79dab049b484")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fd5a9b1a-13f3-42f4-a56f-b6ded569adca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a33ae42e-c8c0-4303-b0f2-8307eb56d4ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="48769465-8659-4439-8fcb-57e7c7fdc695")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="96f6991d-4487-4640-8679-0a4a5ba4d5c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="561fd245-0b09-4508-b6b5-987577eb7d58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6c7f8244-57a0-4e1e-91a6-4b629dc002a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="54e3432e-01cb-418d-9328-45eb257e1ba3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="806c14a6-8503-4f88-a194-a192d761dfd5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c4a99eb4-8e1d-44f4-bf15-b7646e8eca9e")>]

# %%
company_names=[]
for i in companies_tags:
    company_names.append(i.text)
company_names
# Out:
# ['Datamatics Global Services Ltd',
#  'ALTEN CALSOFT LABS (INDIA) PRIVATE LIMITED',
#  'Publicis Groupe',
#  'Bidgely Technologies Private Limited',
#  'Goals 101 Data Solutions Pvt. Ltd.',
#  'McAfee Software (India) Pvt. Ltd',
#  'Onward Technologies Limited',
#  'Teamware Solutions',
#  'Mindtree Limited',
#  'Western Digital',
#  'Western Digital',
#  'Western Digital',
#  'PERSOLKELLY INDIA PRIVATE LIMITED',
#  'Ara Resources',
#  'Novotree Minds Consulting Pvt Limited',
#  'Gojek Tech',
#  'GO-JEK India',
#  'IBM India Pvt. Limited',
#  'IBM India Pvt. Limited',
#  'Perform Group']

# %%
#extracting locations
location_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']//span[1]") #span is used at the end to extract only the 1st index which is location
location_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="14658d46-34e9-40a6-8688-4a0e0cfbd34f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b0a85c7e-296c-48df-8242-3e04d3f70a21")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="82eb4157-11e9-49f0-9cb7-b109d5afdad8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="971e7ec9-2349-4deb-b59e-333bbd4e0db0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f8cf3ad3-dcf9-4a35-be07-c3642fb8b1e6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ec7f3819-f0c1-4f11-80c4-21194769929a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6171c8fd-bde7-4d0e-b3cf-9835e2856a11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9b4ebd0e-1314-4561-8657-a206f28bc956")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f51d0312-a087-476f-bb39-6ea706a80bbd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d87e95ca-f1c2-47aa-8e58-68cbeb6d96c1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ab6218bd-c4cc-49a4-914a-e8d05f76567e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f36ae873-0c08-402e-81fc-77edcb52925a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6b7249bf-c9db-4191-b300-a33fab7a042d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f2591daa-c041-4a1a-860f-e9fd4927c3c6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a2eb310d-de62-4f04-b0be-8004aebd23c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6d30433d-36b7-4430-b5b2-44228003dd15")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f5942d90-7a86-4931-ab4d-11f9f5693a14")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="8e135752-5cd5-444f-855d-ef1c13dd3859")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ef52ca9b-eabc-4ec9-947b-be2b29c8ecea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fbf84e75-c511-4687-8d40-105050ff5266")>]

# %%
locations_names=[]
for i in location_tags:
    locations_names.append(i.text)
locations_names
# Out:
# ['Bangalore/Bengaluru',
#  'Bangalore/Bengaluru(Dairy Circle)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'New Delhi, Bangalore/Bengaluru, Delhi / NCR',
#  'Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
url = driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
url
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="417b9fe5-eb3c-4431-8545-c31c4fe882c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="
px=1',
#  'https://www.naukri.com/job-listings-data-scientist-4-western-digital-bangalore-bengaluru-6-to-8-years-030821500721?src=jobsearchDesk&sid=16281453565346264&xp=12&px=1',
#  'https://www.naukri.com/job-listings-data-scientist-sr-data-scientist-persolkelly-india-private-limited-bangalore-bengaluru-4-to-9-years-030821000159?src=jobsearchDesk&sid=16281453565346264&xp=13&px=1',
#  'https://www.naukri.com/job-listings-senior-software-engineer-data-scientist-ara-resources-bangalore-bengaluru-6-to-10-years-290721906399?src=jobsearchDesk&sid=16281453565346264&xp=14&px=1',
#  'https://www.naukri.com/job-listings-senior-associate-data-scientist-novotree-minds-consulting-pvt-limited-bangalore-bengaluru-4-to-7-years-300721001832?src=jobsearchDesk&sid=16281453565346264&xp=15&px=1',
#  'https://www.naukri.com/job-listings-senior-data-scientist-gojek-tech-bangalore-bengaluru-4-to-8-years-290721501291?src=jobsearchDesk&sid=16281453565346264&xp=16&px=1',
#  'https://www.naukri.com/job-listings-senior-data-scientist-go-jek-india-bangalore-bengaluru-6-to-12-years-290721501288?src=jobsearchDesk&sid=16281453565346264&xp=17&px=1',
#  'https://www.naukri.com/job-listings-senior-data-scientist-ibm-india-pvt-limited-bangalore-bengaluru-5-to-10-years-260721907182?src=jobsearchDesk&sid=16281453565346264&xp=18&px=1',
#  'https://www.naukri.com/job-listings-sr-data-scientist-ibm-india-pvt-limited-bangalore-bengaluru-8-to-12-years-230721906918?src=jobsearchDesk&sid=16281453565346264&xp=19&px=1',
#  'https://www.naukri.com/job-listings-sr-data-scientist-perform-group-bangalore-bengaluru-3-to-7-years-290721501445?src=jobsearchDesk&sid=16281453565346264&xp=20&px=1']

# %%
job_descriptions = []
for i in job_openings_urls:
    driver.get(i)
#Extracting job title
    try:
        job_description = driver.find_element_by_xpath("//div[@class='dang-inner-html']//li[1]")
        job_descriptions.append(job_description.text)
    except:
        job_descriptions.append("--")

job_descriptions
# Out:
# ['The hiring is for a single Data Scientist (7-8+yrs) as he/she shall be an individual contributor.',
#  'Participate in customer workshops to understand customer problems and design solutions with Advanced Analytics',
#  'Work with stakeholders throughout the organization to identify opportunities for leveraging company data to drive business solutions.',
#  'Research and develop advanced statistical and machine learning models for analysis of large-scale, high-dimensional data.',
#  'Work as part of a product team in defining, prototyping and implementing data science models/algorithms as part of the product.',
#  '--',
#  '--',
#  'Dynamic recruiting professional with 7 - 10 years of high-performance tech recruiting experience with search firms and /or mid-large-sized technology companies.',
#  '3-5 years of hands-on experience in in data science, applied statistics, machine learning, data mining, statistical modeling tools and underlying algorithms 3-5 years of hands-on experience building production grade machine learning enabled solutions end to end.',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  '--',
#  'Build models (or ML models) that generate or lead to the answer to some of the most challenging questions we have',
#  'Build models (or ML models) that generate or lead to the answer to some of the most challenging questions we have',
#  '--',
#  '--',
#  'Prior experience developing deep learning models for computer vision applications. Hands on experience in areas like image classication, object detection and instance segmentation.']

# %%
print(len(job_titles),len(company_names),len(job_descriptions),len(locations_names))
# Out:
# 20 20 20 20

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_titles
jobs['company']=company_names
jobs['location']=locations_names
jobs['description']=job_descriptions

# %%
jobs
# Out:
#                                         title  \
# 0                       Senior Data Scientist
# 1                         Lead Data Scientist
# 2                       Senior Data Scientist
# 3                       Senior Data Scientist
# 4                       Senior Data Scientist
# 5                              DATA SCIENTIST
# 6             Data Scientist - Permanent Role
# 7     Data Engineers , Data Scientist and SAP
# 8                     Python - Data Scientist
# 9            Western Digital Data Scientist 3
# 10             Western Digital Data Scientist
# 11                           Data Scientist 4
# 12          Data Scientist /Sr.Data Scientist
# 13  Senior Software Engineer - Data Scientist
# 14          Senior Associate - Data Scientist
# 15                      Senior Data Scientist
# 16                      Senior Data Scientist
# 17                      Senior Data Scientist
# 18                          Sr Data Scientist
# 19                        Sr . Data Scientist
#
#                                        company  \
# 0               Datamatics Global Services Ltd
# 1   ALTEN CALSOFT LABS (INDIA) PRIVATE LIMITED
# 2                              Publicis Groupe
# 3         Bidgely Technologies Private Limited
# 4           Goals 101 Data Solutions Pvt. Ltd.
# 5             McAfee Software (India) Pvt. Ltd
# 6                  Onward Technologies Limited
# 7                           Teamware Solutions
# 8                             Mindtree Limited
# 9                              Western Digital
# 10                             Western Digital
# 11                             Western Digital
# 12           PERSOLKELLY INDIA PRIVATE LIMITED
# 13                               Ara Resources
# 14       Novotree Minds Consulting Pvt Limited
# 15                                  Gojek Tech
# 16                                GO-JEK India
# 17                      IBM India Pvt. Limited
# 18                      IBM India Pvt. Limited
# 19                               Perform Group
#
#                                              location  \
# 0                                 Bangalore/Bengaluru
# 1                   Bangalore/Bengaluru(Dairy Circle)
# 2                                 Bangalore/Bengaluru
# 3                                 Bangalore/Bengaluru
# 4         New Delhi, Bangalore/Bengaluru, Delhi / NCR
# 5                                 Bangalore/Bengaluru
# 6   Hyderabad/Secunderabad, Chennai, Bangalore/Ben...
# 7                                 Bangalore/Bengaluru
# 8                                 Bangalore/Bengaluru
# 9                                 Bangalore/Bengaluru
# 10                                Bangalore/Bengaluru
# 11                                Bangalore/Bengaluru
# 12                                Bangalore/Bengaluru
# 13                                Bangalore/Bengaluru
# 14                                Bangalore/Bengaluru
# 15                                Bangalore/Bengaluru
# 16                                Bangalore/Bengaluru
# 17                                Bangalore/Bengaluru
# 18                                Bangalore/Bengaluru
# 19                                Bangalore/Bengaluru
#
#                                           description
# 0   The hiring is for a single Data Scientist (7-8...
# 1   Participate in customer workshops to understan...
# 2   Work with stakeholders throughout the organiza...
# 3   Research and develop advanced statistical and ...
# 4   Work as part of a product team in defining, pr...
# 5                                                  --
# 6                                                  --
# 7   Dynamic recruiting professional with 7 - 10 ye...
# 8   3-5 years of hands-on experience in in data sc...
# 9                                                  --
# 10                                                 --
# 11                                                 --
# 12                                                 --
# 13                                                 --
# 14                                                 --
# 15  Build models (or ML models) that generate or l...
# 16  Build models (or ML models) that generate or l...
# 17                                                 --
# 18                                                 --
# 19  Prior experience developing deep learning mode...

# %%
a=jobs
b=a[:10]
b
# Out:
#                                      title  \
# 0                    Senior Data Scientist
# 1                      Lead Data Scientist
# 2                    Senior Data Scientist
# 3                    Senior Data Scientist
# 4                    Senior Data Scientist
# 5                           DATA SCIENTIST
# 6          Data Scientist - Permanent Role
# 7  Data Engineers , Data Scientist and SAP
# 8                  Python - Data Scientist
# 9         Western Digital Data Scientist 3
#
#                                       company  \
# 0              Datamatics Global Services Ltd
# 1  ALTEN CALSOFT LABS (INDIA) PRIVATE LIMITED
# 2                             Publicis Groupe
# 3        Bidgely Technologies Private Limited
# 4          Goals 101 Data Solutions Pvt. Ltd.
# 5            McAfee Software (India) Pvt. Ltd
# 6                 Onward Technologies Limited
# 7                          Teamware Solutions
# 8                            Mindtree Limited
# 9                             Western Digital
#
#                                             location  \
# 0                                Bangalore/Bengaluru
# 1                  Bangalore/Bengaluru(Dairy Circle)
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4        New Delhi, Bangalore/Bengaluru, Delhi / NCR
# 5                                Bangalore/Bengaluru
# 6  Hyderabad/Secunderabad, Chennai, Bangalore/Ben...
# 7                                Bangalore/Bengaluru
# 8                                Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru
#
#                                          description
# 0  The hiring is for a single Data Scientist (7-8...
# 1  Participate in customer workshops to understan...
# 2  Work with stakeholders throughout the organiza...
# 3  Research and develop advanced statistical and ...
# 4  Work as part of a product team in defining, pr...
# 5                                                 --
# 6                                                 --
# 7  Dynamic recruiting professional with 7 - 10 ye...
# 8  3-5 years of hands-on experience in in data sc...
# 9                                                 --

# %% [markdown]
# # Answer for question 3

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c8032e95-9d54-4fef-946b-dc673afe8012")>

# %%
search_job.send_keys("Data scientist")

# %%
search_btn = driver.find_element_by_class_name('btn')
search_btn.click()

# %%
location_filter=driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[1]/div[2]/div[3]/label/i') 
location_filter.click()

# %%
salary_filter=driver.find_element_by_xpath('/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[4]/div[2]/div[2]/label/i') 
salary_filter.click()

# %%
#extracting all the tags having job titles
titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']") #element's' gives us all the elements
titles_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e3a062f6-54dd-447d-832b-b08491d30859")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4ce11cf7-ef50-4dda-ac99-a5861353fbec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="392aba7c-c01f-4d74-af76-ac9612b5073b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6d1106cc-8878-4d26-ac76-a80c2c2a7ad4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2e71a35e-0080-4eb0-8956-98d570f12e55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="7b0f44b7-b0dc-45c8-8065-110966ce61bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="408d91a4-19cf-499f-88b6-ac484143591a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f5219a3a-3fd1-4cb5-90c0-a0c670504b0d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b6442ac5-3044-4175-8fc9-3e2c133abf57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5a514412-75bf-4701-a967-f6923702066a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4d3c063c-07aa-474c-afad-6b16243e90d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d2224541-b601-437a-b6f7-66ca6dd3c29e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b1218165-4dc6-4e3d-bef5-20a15851f6f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5acef8eb-d88c-4e7e-b7b7-19f0ae8fa31d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="bc0cf4c8-3419-45de-b140-f01bcd5c1349")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="0396ff64-b506-4dbf-a65b-aa07e3e80cf0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="0796c52a-ac96-42fc-9696-de864eb72aed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ecf6097d-0dd2-464a-b5b2-2e3ad49120e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ed886300-b7d1-41e7-81e7-13b6ba88ecb9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f53f1125-181e-41f4-aacc-61c1c1e4bcc6")>]

# %%
job_titles=[]
for i in titles_tags:
    job_titles.append(i.text.replace('\n',''))
job_titles
# Out:
# ['Immediate Openings For DATA Scientist with 6 To 7 yrs of Experience',
#  'Senior Data Scientist',
#  'Hiring Data Scientist Develope || IDS Infotech LTD || (Permanent WFH)',
#  'Hiring Data Scientist Develope || IDS Infotech LTD || (Permanent WFH)',
#  'Senior Data Scientist - Noida',
#  'Data Scientist / Data Analyst',
#  'Only Fresher / Data Scientist / Data Analyst / Analytics - MNC Jobs',
#  'Data Scientist',
#  'Data Scientist/Data Analyst /Business Analyst',
#  'Data Scientist',
#  'Data Scientist - Machine Learning/NLP',
#  'Data Scientist - Machine Learning/NLP',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist ( Machine Learning , Pyspark, Cloud , DevOps)',
#  'Data Scientist ( Machine Learning , Pyspark, Cloud , DevOps)',
#  'Data Scientist']

# %%
#extracting all the company names
companies_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
companies_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="41ba562b-ee45-44f9-a2c7-d410c91efd83")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="1783bce2-ea09-4f4e-8e16-723138d4255e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="32c99af1-635d-44a5-8e03-f28b6ddd801f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3af28e71-213d-4a53-92b3-41adf72a38f7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="eb7310dd-ba11-4fe5-bc50-def35a287308")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="444aa34c-0840-47ca-858b-f42aa9897068")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="534c09ea-4ca0-438b-92b2-c6940e79d75a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="53779062-6023-4439-8339-f685fbbd4f59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e736a673-a924-4460-a876-05b643c08441")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c8285528-85b7-44ae-90e6-50ab3b476607")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f825d72c-cbd9-4111-b852-b0f16baee9d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c697482b-e3df-4fae-a40a-2cc5f795b16a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9973415b-2433-4e28-b39e-49fee93277b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="31c3420b-4bf6-42e4-a304-b41732f2f2e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="64cd4785-1122-4b4e-bb96-de1db34f41d9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="21c06644-0781-496f-ab16-de9b6bae9fcb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a83115f7-6d94-4fe8-9288-cbf58021e0a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="899c0f3e-b32d-47fa-ac68-2108035052ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e7a21821-62bd-4e39-83b5-2fa5d524ff76")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="338a5319-b806-49c2-bb4c-98c97280918d")>]

# %%
company_names=[]
for i in companies_tags:
    company_names.append(i.text)
company_names
# Out:
# ['Entune IT Consulting Private Limited',
#  'inVentiv International Pharma Services Pvt. Ltd.',
#  'IDS Infotech Ltd.',
#  'IDS Infotech Ltd.',
#  'Optum Global Solutions (India) Private Limited',
#  'CARS24',
#  'GABA Consultancy services',
#  'Decimal Technologies Pvt Ltd.',
#  'Inflexion Analytix Private Limited',
#  'R Systems International Ltd.',
#  'TalPro',
#  'TalPro',
#  'AlgoScale Technologies Private Limited',
#  'Fractal Analytics',
#  'Ashkom Media India Private Limited',
#  'BlackBuck',
#  'Country Veggie',
#  'JUMBO CONSULTANTS',
#  'JUMBO CONSULTANTS',
#  'UrbanClap']

# %%
#extracting years of experience
experience_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']//span") #span is used at the end to extract only the years
experience_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="94eed8f9-c9e8-4fa5-8b1b-cb95a1a98a6c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fa8bec3d-f92d-479a-9a6e-8c9d3a97924c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4a8f3d16-45ae-4e3f-bcd6-722b0469b25e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a4501ed8-7c95-43b4-8fcc-e6370c1f2059")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="97c1e1b7-cf53-4e72-a87e-1f5cb0a01878")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="74d22dec-3545-4e06-bfe5-6a38b2a5da39")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="0c5bc88e-71ba-4954-bb49-bce6d65a56b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f8b0b5f0-6176-441f-908b-2a58ea7a2843")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="72375307-61eb-4e31-9914-b75faee91e8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9d43a2a6-18f7-4dd5-aec9-3daa6bc95c0f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="1a5b8f19-623f-493a-b4a2-cbabd4af210e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="40e209d4-e5fc-418f-972d-ff2aee63cf90")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="cb6f0306-1ff5-4027-a64d-e4b5034e6ba7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e5b3db3f-1fbf-4b78-9a67-ee9ad47f4fff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="032ec866-88de-47e9-838d-6bf610907642")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="78e28ad9-47aa-4844-b743-38dbd04d210e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="151a8529-3cff-4efd-8d07-2d6dc432b969")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f8dc7ce2-04cd-4196-af1c-90610b45e962")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="0c369855-5226-4a35-b503-a2821661a813")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="89356f28-a233-4104-88a2-3d9cc281b6ed")>]

# %%
experience_list=[]
for i in experience_tags:
    experience_list.append(i.text)
experience_list
# Out:
# ['5-8 Yrs',
#  '3-6 Yrs',
#  '5-10 Yrs',
#  '5-10 Yrs',
#  '2-6 Yrs',
#  '1-5 Yrs',
#  '0-0 Yrs',
#  '1-3 Yrs',
#  '0-3 Yrs',
#  '5-10 Yrs',
#  '2-6 Yrs',
#  '2-4 Yrs',
#  '2-6 Yrs',
#  '3-7 Yrs',
#  '3-8 Yrs',
#  '3-7 Yrs',
#  '1-3 Yrs',
#  '4-9 Yrs',
#  '4-9 Yrs',
#  '1-3 Yrs']

# %%
#extracting locations
location_tags=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']//span[1]") #span is used at the end to extract only the 1st index which is location
location_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="29250084-84b3-4181-97b1-cd8172e4a36b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c883c4a9-e7f2-409a-b508-415948c04b94")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="af34d7c0-1b00-423c-8516-81ef83c2b390")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3c585b32-1ec0-427a-9a72-c3bd671281f3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9418c21d-e7f7-4b39-b59e-f599601287cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9a849d72-46f8-4055-bf7b-a791fa3980d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c7e9e1fe-8b3d-479d-b9a3-7bce8b7f220d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f6465c5b-e8b6-41db-963e-81e822f0141c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c1de9bc5-14b2-4280-bf4d-3f878481f71f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="7c85e4fc-aad5-4af9-8eac-5620a039fe72")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a1681198-d9f5-4508-8815-4be0ef02d5f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="8c6cc7c3-41af-4345-99d9-17bfceed87f8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="aa838b56-aa8c-4fb3-978e-d65cd26b693b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e8d0dde9-0f8a-441e-85f3-1043491fc529")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="90b5cb5b-a45f-44c8-916d-b596dfce6722")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="8e393871-578a-4d46-9c39-09ef8312dc4e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="49426570-10f3-4bb6-a011-03490c1b33f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="acd1f434-7676-4c68-89b5-4cf03696cf79")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="26623b4e-2409-4c3b-9036-2c07f24d09b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e05b3f5a-0450-4fb3-b180-8c9c08170b99")>]

# %%
locations_names=[]
for i in location_tags:
    locations_names.append(i.text)
locations_names
# Out:
# ['Kolkata, Hyderabad/Secunderabad, Pune, Ahmedabad, Chennai, Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)',
#  'Hyderabad/Secunderabad, Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Chandigarh, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru, Delhi / NCR',
#  'Chandigarh, Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru, Delhi / NCR',
#  'Noida',
#  'Gurgaon/Gurugram',
#  'Noida, Gurgaon/Gurugram, Delhi / NCR',
#  'Gurgaon/Gurugram',
#  'Pune, Delhi / NCR, Mumbai (All Areas)',
#  'Noida(Sector-59 Noida)',
#  'Gurgaon/Gurugram',
#  'Gurgaon/Gurugram',
#  'Noida(Sector-62 Noida)',
#  'Mumbai, Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Noida',
#  'Gurgaon, Bengaluru',
#  'Bharuch, Jaipur, Bhopal, Mumbai, Jhansi, Nagpur, Ghaziabad, Jaunpur, Kanpur, Delhi, Lucknow, Agra, Gurgaon, Rajkot, Bengaluru',
#  'Remote',
#  'Remote',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru']

# %%
print(len(job_titles),len(company_names),len(experience_list),len(locations_names))
# Out:
# 20 20 20 20

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['title']=job_titles
jobs['company']=company_names
jobs['experience']=experience_list
jobs['location']=locations_names

# %%
jobs
# Out:
#                                                 title  \
# 0   Immediate Openings For DATA Scientist with 6 T...
# 1                               Senior Data Scientist
# 2   Hiring Data Scientist Develope || IDS Infotech...
# 3   Hiring Data Scientist Develope || IDS Infotech...
# 4                       Senior Data Scientist - Noida
# 5                       Data Scientist / Data Analyst
# 6   Only Fresher / Data Scientist / Data Analyst /...
# 7                                      Data Scientist
# 8       Data Scientist/Data Analyst /Business Analyst
# 9                                      Data Scientist
# 10              Data Scientist - Machine Learning/NLP
# 11              Data Scientist - Machine Learning/NLP
# 12                                     Data Scientist
# 13                                     Data Scientist
# 14                                     Data Scientist
# 15                                     Data Scientist
# 16                                     Data Scientist
# 17  Data Scientist ( Machine Learning , Pyspark, C...
# 18  Data Scientist ( Machine Learning , Pyspark, C...
# 19                                     Data Scientist
#
#                                              company experience  \
# 0               Entune IT Consulting Private Limited    5-8 Yrs
# 1   inVentiv International Pharma Services Pvt. Ltd.    3-6 Yrs
# 2                                  IDS Infotech Ltd.   5-10 Yrs
# 3                                  IDS Infotech Ltd.   5-10 Yrs
# 4     Optum Global Solutions (India) Private Limited    2-6 Yrs
# 5                                             CARS24    1-5 Yrs
# 6                          GABA Consultancy services    0-0 Yrs
# 7                      Decimal Technologies Pvt Ltd.    1-3 Yrs
# 8                 Inflexion Analytix Private Limited    0-3 Yrs
# 9                       R Systems International Ltd.   5-10 Yrs
# 10                                            TalPro    2-6 Yrs
# 11                                            TalPro    2-4 Yrs
# 12            AlgoScale Technologies Private Limited    2-6 Yrs
# 13                                 Fractal Analytics    3-7 Yrs
# 14                Ashkom Media India Private Limited    3-8 Yrs
# 15                                         BlackBuck    3-7 Yrs
# 16                                    Country Veggie    1-3 Yrs
# 17                                 JUMBO CONSULTANTS    4-9 Yrs
# 18                                 JUMBO CONSULTANTS    4-9 Yrs
# 19                                         UrbanClap    1-3 Yrs
#
#                                              location
# 0   Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 1   Hyderabad/Secunderabad, Gurgaon/Gurugram, Bang...
# 2   Chandigarh, Hyderabad/Secunderabad, Chennai, B...
# 3   Chandigarh, Hyderabad/Secunderabad, Chennai, B...
# 4                                               Noida
# 5                                    Gurgaon/Gurugram
# 6                Noida, Gurgaon/Gurugram, Delhi / NCR
# 7                                    Gurgaon/Gurugram
# 8               Pune, Delhi / NCR, Mumbai (All Areas)
# 9                              Noida(Sector-59 Noida)
# 10                                   Gurgaon/Gurugram
# 11                                   Gurgaon/Gurugram
# 12                             Noida(Sector-62 Noida)
# 13      Mumbai, Gurgaon/Gurugram, Bangalore/Bengaluru
# 14                                              Noida
# 15                                 Gurgaon, Bengaluru
# 16  Bharuch, Jaipur, Bhopal, Mumbai, Jhansi, Nagpu...
# 17                                             Remote
# 18                                             Remote
# 19              Gurgaon/Gurugram, Bangalore/Bengaluru

# %%
a=jobs
b=a[:10]
b
# Out:
#                                                title  \
# 0  Immediate Openings For DATA Scientist with 6 T...
# 1                              Senior Data Scientist
# 2  Hiring Data Scientist Develope || IDS Infotech...
# 3  Hiring Data Scientist Develope || IDS Infotech...
# 4                      Senior Data Scientist - Noida
# 5                      Data Scientist / Data Analyst
# 6  Only Fresher / Data Scientist / Data Analyst /...
# 7                                     Data Scientist
# 8      Data Scientist/Data Analyst /Business Analyst
# 9                                     Data Scientist
#
#                                             company experience  \
# 0              Entune IT Consulting Private Limited    5-8 Yrs
# 1  inVentiv International Pharma Services Pvt. Ltd.    3-6 Yrs
# 2                                 IDS Infotech Ltd.   5-10 Yrs
# 3                                 IDS Infotech Ltd.   5-10 Yrs
# 4    Optum Global Solutions (India) Private Limited    2-6 Yrs
# 5                                            CARS24    1-5 Yrs
# 6                         GABA Consultancy services    0-0 Yrs
# 7                     Decimal Technologies Pvt Ltd.    1-3 Yrs
# 8                Inflexion Analytix Private Limited    0-3 Yrs
# 9                      R Systems International Ltd.   5-10 Yrs
#
#                                             location
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 1  Hyderabad/Secunderabad, Gurgaon/Gurugram, Bang...
# 2  Chandigarh, Hyderabad/Secunderabad, Chennai, B...
# 3  Chandigarh, Hyderabad/Secunderabad, Chennai, B...
# 4                                              Noida
# 5                                   Gurgaon/Gurugram
# 6               Noida, Gurgaon/Gurugram, Delhi / NCR
# 7                                   Gurgaon/Gurugram
# 8              Pune, Delhi / NCR, Mumbai (All Areas)
# 9                             Noida(Sector-59 Noida)

# %% [markdown]
# # Answer for question 5

# %%
url = ' https://www.glassdoor.co.in/Salaries/index.htm'
driver.get(url)

# %%
#finding element by xpath
search_job = driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div[1]/div/div/form/input[5]')
search_job.send_keys("Data scientist")

# %%
#finding element by xpath
search_loc = driver.find_element_by_xpath('/html/body/div[3]/div/div[1]/div[1]/div/div/form/input[6]')
search_loc.send_keys("Noida")

# %%
search_btn = driver.find_element_by_class_name('gd-btn-mkt')
search_btn.click()

# %%
#extracting all the tags having job titles
titles_tags=driver.find_elements_by_xpath("//a[@class='css-f3vw95 e1aj7ssy3']") #element's' gives us all the elements
titles_tags
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e54e6b67-f1c7-4b4e-9399-6d9bdae985fb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="912250e8-4b8e-4785-bcb3-78a5fdf60d63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="723f5f83-99b1-443a-a6fc-fb25b9e3a8b6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="966aa035-cfd0-49f4-8139-1d4f1a0a279f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ab09e605-4d67-46fd-9f98-37f210c6eb65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="1c886e69-146c-493c-bd0d-a2dfdc626a91")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2a345302-0633-4650-a8f4-bc2059634e1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="cf3b6adb-3142-4852-8a56-81fe547e022f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="20bfda72-c809-4aee-8833-c897316679bf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="4d5237ae-1343-4bf0-810b-51632d6625a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="eba78198-eb77-4ac6-8beb-49530b51d136")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b7adce32-9686-4a0e-87a3-dd7c6a67abe9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2e223d65-fab9-4e98-a218-54e47f71fef8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="688d0b2b-b260-4b7d-adfb-b37ed2683c8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9e230d53-faf7-491d-b996-64e91bdb98ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="0c330186-c7c1-4231-8bc1-9478b897c4f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="52946ede-51dc-4217-8da0-110fc00a8125")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5097024f-b96f-4d08-9b3a-e08ceaf54535")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="442c7f1c-a77f-4123-a874-7297f0465bbb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="25231af4-e5a0-4853-8918-3f2d5c56778f")>]

# %%
job_titles=[]
for i in titles_tags:
    job_titles.append(i.text.replace('\n',''))
job_titles
# Out:
# ['Tata Consultancy Services',
#  'IBM',
#  'Accenture',
#  'Delhivery',
#  'Ericsson-Worldwide',
#  'UnitedHealth Group',
#  'Valiance Solutions',
#  'EXL Service',
#  'Optum',
#  'Optum Global Solutions',
#  'ZS Associates',
#  'Innovaccer',
#  'OYO',
#  'Nagarro',
#  'Cognizant Technology Solutions',
#  'CARS24.com',
#  'dunnhumby',
#  'Vidooly Media Tech',
#  'Tech Mahindra',
#  'Fresher']

# %%
#extracting all the average salary
average_salary=driver.find_elements_by_xpath("//div[@class='col-12 col-lg-4 px-lg-0 d-flex align-items-baseline']//h3")
average_salary
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="66ca63da-df1b-41b1-aff5-2edbbafb6205")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6762797f-81a6-4436-ae8e-e3bd91abf4b4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="54a52a2e-8f5a-4e0d-8364-79fd3d0cb9a0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="aeb9450a-1b7d-48a7-a30e-007d625b5226")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="72975dcd-2a50-44a7-bb3d-55043d10aca5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="400eeba1-2af4-4e1a-a768-b880e4b7b289")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="963ba4ad-4df0-43a2-8f24-a075fc2f0291")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9121df99-c52f-4a67-9cb7-f4d3e78438e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d035c961-7c33-41b9-aadd-7c8ca6253c30")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f9661b97-5947-40aa-9d5b-2654e13954b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="143d2b3a-6aa4-4cab-86c5-4ddd05cc6ef1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="977aa9a9-f2a8-404e-b65d-125a96da5707")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9d329bbc-372f-4594-9e18-88a8efca63dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="8e61e5ae-b904-4bea-b360-ba95e66e349b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3cd9084b-9be7-42d8-a8a9-d9df7b8ca361")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3925a356-d94a-430f-af35-e89dcc764c6f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f05da6de-bf9b-4401-80d1-35975debb743")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d8080d90-b4b3-477e-a404-42825e727879")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2d9fadf4-efb4-4e6d-8c12-586d600274f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5f9646dc-93c2-49d5-81b4-14c513d58e8a")>]

# %%
average_salaries=[]
for i in average_salary:
    average_salaries.append(i.text)
average_salaries
# Out:
# ['₹6,12,205',
#  '₹9,00,000',
#  '₹11,63,336',
#  '₹12,18,244',
#  '₹7,39,238',
#  '₹12,80,000',
#  '₹8,63,750',
#  '₹11,10,000',
#  '₹14,23,677',
#  '₹13,28,697',
#  '₹11,42,356',
#  '₹12,09,040',
#  '₹14,15,338',
#  '₹10,22,074',
#  '₹10,09,021',
#  '₹10,00,000',
#  '₹10,55,478',
#  '₹34,157',
#  '₹10,54,402',
#  '₹80,000']

# %%
#extracting rating of the company
company_rating=driver.find_elements_by_xpath("//div[@class='d-flex align-items-center mt-xxsm']//span")
company_rating
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="
#  '4.2',
#  '★']

# %%
company_ratingonly = []
for i in range(0, len(company_ratings),2):
    company_ratingonly.append(company_ratings[i])
company_ratingonly
# Out:
# ['3.9',
#  '3.9',
#  '4.1',
#  '3.9',
#  '4',
#  '3.6',
#  '4.2',
#  '3.6',
#  '3.7',
#  '3.9',
#  '4',
#  '3.8',
#  '3.3',
#  '4',
#  '3.8',
#  '4.1',
#  '4.1',
#  '3.7',
#  '3.6',
#  '4.2']

# %%
#extracting salary range
salary_range=driver.find_elements_by_xpath("//span[@class='d-block d-lg-none m-0 css-1b6bxoo']") 
salary_range
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="7eaf306d-3447-4094-b729-f8cf969fa20d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a5295daa-4b90-45f8-8ce6-4aa289954a78")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f50b5e38-0e19-4078-bab6-09b0a1f70681")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="19eaa333-46ef-437b-88e4-eef18402c2e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6db9ac6b-494d-478b-9f1d-c11a7319f02d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="926f4ba2-cd8a-4c2b-a992-feb97a10a34b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e959176f-5444-456f-bde5-832c89221d2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="0119f882-7fd9-4c6b-8e51-2f85d4a3b76a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="2d57ec6b-71f1-487e-94e1-792e65dabe3f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="db608914-7181-49ef-ab81-f40da3d5392c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="64acd7ab-7f9f-45d5-be72-c48b06f65233")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f4f30a8e-5bf6-49db-9031-a2db7d0cfab0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5307798a-400f-47a0-871d-404bb7bc1c34")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="8382f222-5cf7-4d1b-9698-4e1f1fc74587")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="14c667ce-5a9e-4a5c-8c43-9f877dce8f9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a31b04a1-d239-4161-a69f-30731edfe0dc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="b1e0bb4f-2fe2-4a3d-88f7-bd7b9ed5466d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="38ddec5f-70eb-456f-b484-bdce03742610")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6f580ba0-3cb6-45f2-99de-3b7cd508a2d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c62bb2c3-d951-4de7-90e8-431960c7261f")>]

# %%
salary_ranges=[]
for i in salary_range:
    salary_ranges.append(i.text)
salary_ranges
# Out:
# ['Range: ₹3L - ₹13L',
#  'Range: ₹6L - ₹27L',
#  'Range: ₹6L - ₹22L',
#  'Range: ₹5L - ₹1Cr',
#  'Range: ₹4L - ₹16L',
#  'Range: ₹8L - ₹15L',
#  'Range: ₹5L - ₹15L',
#  'Range: ₹6L - ₹15L',
#  'Range: ₹8L - ₹20L',
#  'Range: ₹4L - ₹22L',
#  'Range: ₹2L - ₹18L',
#  'Range: ₹6L - ₹17L',
#  'Range: ₹10L - ₹21L',
#  'Range: ₹4L - ₹16L',
#  'Range: ₹8L - ₹13L',
#  'Range: ₹9L - ₹15L',
#  'Range: ₹8L - ₹20L',
#  'Range: ₹12T - ₹63T',
#  'Range: ₹4L - ₹17L',
#  'Range: ₹25T - ₹1L']

# %%
print(len(job_titles),len(average_salaries),len(company_ratingonly),len(salary_ranges))
# Out:
# 20 20 20 20

# %%
import pandas as pd
jobs=pd.DataFrame({})
jobs['company_names']=job_titles
jobs['Average_salary']=average_salaries
jobs['Company rating']=company_ratingonly
jobs['Salary range']=salary_ranges

# %%
jobs
# Out:
#                      company_names Average_salary Company rating  \
# 0        Tata Consultancy Services      ₹6,12,205            3.9
# 1                              IBM      ₹9,00,000            3.9
# 2                        Accenture     ₹11,63,336            4.1
# 3                        Delhivery     ₹12,18,244            3.9
# 4               Ericsson-Worldwide      ₹7,39,238              4
# 5               UnitedHealth Group     ₹12,80,000            3.6
# 6               Valiance Solutions      ₹8,63,750            4.2
# 7                      EXL Service     ₹11,10,000            3.6
# 8                            Optum     ₹14,23,677            3.7
# 9           Optum Global Solutions     ₹13,28,697            3.9
# 10                   ZS Associates     ₹11,42,356              4
# 11                      Innovaccer     ₹12,09,040            3.8
# 12                             OYO     ₹14,15,338            3.3
# 13                         Nagarro     ₹10,22,074              4
# 14  Cognizant Technology Solutions     ₹10,09,021            3.8
# 15                      CARS24.com     ₹10,00,000            4.1
# 16                       dunnhumby     ₹10,55,478            4.1
# 17              Vidooly Media Tech        ₹34,157            3.7
# 18                   Tech Mahindra     ₹10,54,402            3.6
# 19                         Fresher        ₹80,000            4.2
#
#           Salary range
# 0    Range: ₹3L - ₹13L
# 1    Range: ₹6L - ₹27L
# 2    Range: ₹6L - ₹22L
# 3    Range: ₹5L - ₹1Cr
# 4    Range: ₹4L - ₹16L
# 5    Range: ₹8L - ₹15L
# 6    Range: ₹5L - ₹15L
# 7    Range: ₹6L - ₹15L
# 8    Range: ₹8L - ₹20L
# 9    Range: ₹4L - ₹22L
# 10   Range: ₹2L - ₹18L
# 11   Range: ₹6L - ₹17L
# 12  Range: ₹10L - ₹21L
# 13   Range: ₹4L - ₹16L
# 14   Range: ₹8L - ₹13L
# 15   Range: ₹9L - ₹15L
# 16   Range: ₹8L - ₹20L
# 17  Range: ₹12T - ₹63T
# 18   Range: ₹4L - ₹17L
# 19   Range: ₹25T - ₹1L

# %%
a=jobs
b=a[:10]
b
# Out:
#                company_names Average_salary Company rating       Salary range
# 0  Tata Consultancy Services      ₹6,12,205            3.9  Range: ₹3L - ₹13L
# 1                        IBM      ₹9,00,000            3.9  Range: ₹6L - ₹27L
# 2                  Accenture     ₹11,63,336            4.1  Range: ₹6L - ₹22L
# 3                  Delhivery     ₹12,18,244            3.9  Range: ₹5L - ₹1Cr
# 4         Ericsson-Worldwide      ₹7,39,238              4  Range: ₹4L - ₹16L
# 5         UnitedHealth Group     ₹12,80,000            3.6  Range: ₹8L - ₹15L
# 6         Valiance Solutions      ₹8,63,750            4.2  Range: ₹5L - ₹15L
# 7                EXL Service     ₹11,10,000            3.6  Range: ₹6L - ₹15L
# 8                      Optum     ₹14,23,677            3.7  Range: ₹8L - ₹20L
# 9     Optum Global Solutions     ₹13,28,697            3.9  Range: ₹4L - ₹22L

# %% [markdown]
# # Answer for question 6

# %%
url = 'https://www.flipkart.com/'
driver.get(url)

# %%
#finding element by xpath
search_item = driver.find_element_by_xpath('/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search_item.send_keys("sunglasses")

# %%
search_btn = driver.find_element_by_class_name('L0Z3Pu')
search_btn.click()

# %%
#extracting all the tags having brand names
brand_names=driver.find_elements_by_xpath("//div[@class='_2WkVRV']") #element's' gives us all the elements
brand_names
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="46768faf-2a67-4b84-879d-86b48065905e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="705ab1a3-3b42-4a08-aa5c-02ea2173bfe1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="49b14663-c2d1-4946-b490-085340463e26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fcb3c3b3-bf49-48bf-9168-d6d0819ea6d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5a9606d7-dd2a-4723-9331-d9c276800e7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="7e848631-3716-4e7c-ac46-fbf5a238a2a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="452a9445-78f3-45c2-9d2c-b25b3ee015e4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a1d7b7b4-8f88-402a-adb8-ac4dc83940b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3f064663-ed13-4580-89e9-baa2a287c928")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5ea1bc20-55d1-4108-9db2-a8349b73483b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="63e5241b-128c-4d6d-9151-0c37fd1ade55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9bf02d92-7b6a-494c-9cb6-24613c1219d2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e49d83da-1cae-43fa-b20d-6125b2a94309")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f9034d43-2e89-43ad-9602-59b1fc30c3e3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="9f9fa545-dcf0-4722-825d-763c2b751c58")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="796b67ba-2963-4b4d-846e-b93e12bbd375")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d4fd0c01-7947-438b-9035-4750d5700928")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="eeddddb2-81b2-403f-90af-54b087133c03")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="fee48b4f-8b16-4ddc-93fd-cc8310049e9c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="28e7f69e-4b6e-4789-a053-c72f95232a11")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="d3e20332-679e-479d-a3f7-0102936a40d8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="e0064d7b-ce62-46f0-a5c0-f945b092a4b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f3ed5fc2-73c9-4dad-9117-53d460aba4e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="3a2d1816-2c5c-42d9-b8cc-af76f145725f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="da9e113a-3ca9-4c1b-ad5a-7d10be280c3d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6264a9c5-53c8-445d-a509-b8bad422ed7b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="aa96a03e-b7e9-43d9-a865-440f04475fef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="84835905-6b7d-48c3-a5b9-995097355e26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="bf71c37e-4e2e-42d8-9beb-ab1d3d801091")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="054b3bb4-44a9-4f5c-b8be-1bd169e036ed")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="49dcfb35-d782-414e-9c6c-65091407f68a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="5b75c120-ded7-4fb0-980f-14fa8daee34d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="145df042-de7f-4a11-80c9-c2c572747ea1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="a3356b9c-c23a-4b91-b7b9-ba426b577be9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="30dfdc53-1e90-4903-94d7-d55d4d2f7a44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="92fd783a-a337-45c5-999f-30557dac8949")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="22d5ca21-5d55-4765-9cd9-d28be3cb9e9f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="48780554-45a2-4103-aa9c-1e7b63400f36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="75806322-4887-4839-b2b6-3131924ff8f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="763c8eec-68b7-448d-af14-b60b5c4514aa")>]

# %%
brand_namesonly=[]
for i in brand_names:
    brand_namesonly.append(i.text.replace('\n',''))
brand_namesonly
# Out:
# ['Wrogn',
#  'HAMIW COLLECTION',
#  'Elligator',
#  'Fastrack',
#  'Fastrack',
#  'Fastrack',
#  'PIRASO',
#  'Villain',
#  'kingsunglasses',
#  'Fastrack',
#  'kingsunglasses',
#  'VINCENT CHASE',
#  'PIRASO',
#  'kingsunglasses',
#  'Fastrack',
#  'ROYAL SON',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'Elligator',
#  'ROYAL SON',
#  'Fastrack',
#  'kingsunglasses',
#  'PHENOMENAL',
#  'Wrogn',
#  'ROZZETTA CRAFT',
#  'Silver Kartz',
#  'hipe',
#  'ROYAL SON',
#  'Fastrack',
#  'Singco India',
#  'Singco India',
#  'ROYAL SON',
#  'Elligator',
#  'Fastrack',
#  'Elligator',
#  'ROZZETTA CRAFT',
#  'kingsunglasses',
#  'Fastrack',
#  'PHENOMENAL',
#  'hipe']

# %%
url1 = driver.find_elements_by_xpath("//nav[@class='yFHi8N']//a")
url1
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="111c4081-b426-4549-853d-2ff7a7079bf0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="f6472e23-c47d-4c7e-8fbb-2868ffbf0520")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="99deda52-175e-4bc5-b48b-84f2da037486")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="cb8fe7e5-0ab7-438b-bf57-40a5a06e50c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="de11b054-6265-4fe2-a8a1-81da6e3cdfb1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="db1fc1b0-3523-426c-a7d9-639cbdf97c95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="6a191644-f006-4ac3-bfa1-43a0f7667dc5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ebfd1332-e360-49e9-bf1a-da58542ebacb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="ef250f9e-f03a-423b-98c9-2b9aacfb4438")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="35318504-a08b-4adb-9a07-f579d3beaf7d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="858fa594-0b69-434c-940d-de85637ab680")>]

# %%
page_url = []
url1 = driver.find_elements_by_xpath("//nav[@class='yFHi8N']//a")
for i in url1:
    page_url.append(i.get_attribute("href"))
page_url
# Out:
# ['https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=8',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=9',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=10',
#  'https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2']

# %%
brand_names1=[]
for i in page_url[:3]:
    driver.get(i)
    brand_names=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")
    for i in brand_names:
        brand_names1.append(i.text)
brand_names1
# Out:
# ['Wrogn',
#  'HAMIW COLLECTION',
#  'Elligator',
#  'Fastrack',
#  'Fastrack',
#  'Fastrack',
#  'kingsunglasses',
#  'Villain',
#  'PIRASO',
#  'kingsunglasses',
#  'Fastrack',
#  'ROYAL SON',
#  'PIRASO',
#  'kingsunglasses',
#  'Fastrack',
#  'ROYAL SON',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'Elligator',
#  'Wrogn',
#  'Fastrack',
#  'Fastrack',
#  'kingsunglasses',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'PHENOMENAL',
#  'Silver Kartz',
#  'ROZZETTA CRAFT',
#  'hipe',
#  'Singco India',
#  'Fastrack',
#  'hipe',
#  'Singco India',
#  'Fastrack',
#  'kingsunglasses',
#  'ROYAL SON',
#  'ROZZETTA CRAFT',
#  'Elligator',
#  'ROYAL SON',
#  'ROYAL SON',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  'PHENOMENAL',
#  'Wrogn',
#  'HIPPON',
#  'DEIXELS',
#  'PIRASO',
#  'ROYAL SON',
#  'Singco',
#  'GANSTA',
#  'AISLIN',
#  'ROYAL SON',
#  'Fastrack',
#  'Fastrack',
#  'NuVew',
#  'Wrogn',
#  'hipe',
#  'ROYAL SON',
#  'Singco India',
#  'ROZZETTA CRAFT',
#  'Fastrack',
#  'DEIXELS',
#  'GANSTA',
#  'ROYAL SON',
#  'Singco India',
#  'ROYAL SON',
#  'Fravy',
#  'hipe',
#  'Fastrack',
#  'kingsunglasses',
#  'hipe',
#  'ROYAL SON',
#  'GANSTA',
#  'Fastrack',
#  'PIRASO',
#  'PIRASO',
#  'PIRASO',
#  'Villain',
#  'PIRASO',
#  'ROYAL SON',
#  'AISLIN',
#  'PHENOMENAL',
#  'NuVew',
#  'Wrogn',
#  'ROZZETTA CRAFT',
#  'ROYAL SON',
#  'Fastrack',
#  'HAMIW COLLECTION',
#  'AISLIN',
#  'Flizz',
#  'United Colors of Benetton',
#  'ROYAL SON',
#  'hipe',
#  'Singco India',
#  'Elligator',
#  'Wrogn',
#  'PHENOMENAL',
#  'Fastrack',
#  'ROZZETTA CRAFT',
#  
5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element="c530ab1d-3229-435f-af3f-0c623f6f0c43")>]

# %%
discount_percentageonly=[]
for i in discount_percentage:
    discount_percentageonly.append(i.text.replace('\n',''))
discount_percentageonly
# Out:
# ['82% off',
#  '84% off',
#  '72% off',
#  '71% off',
#  '77% off',
#  '66% off',
#  '25% off',
#  '88% off',
#  '70% off',
#  '81% off',
#  '68% off',
#  '66% off',
#  '79% off',
#  '82% off',
#  '88% off',
#  '68% off',
#  '87% off',
#  '30% off',
#  '78% off',
#  '53% off',
#  '79% off',
#  '76% off',
#  '28% off',
#  '55% off',
#  '75% off',
#  '84% off',
#  '82% off',
#  '66% off',
#  '80% off',
#  '71% off',
#  '78% off',
#  '78% off',
#  '68% off',
#  '28% off',
#  '25% off',
#  '70% off',
#  '5% off',
#  '60% off',
#  '83% off',
#  '85% off',
#  '81% off',
#  '78% off',
#  '78% off',
#  '82% off',
#  '25% off']

# %%
discount_percentageonly1=[]
for i in page_url[:3]:
    driver.get(i)
    discount_percentage=driver.find_elements_by_xpath("//div[@class='_25b18c']//span")
    for i in discount_percentage:
        discount_percentageonly1.append(i.text)
discount_percentageonly1
# Out:
# ['71% off',
#  '45% off',
#  '88% off',
#  '43% off',
#  '36% off',
#  '25% off',
#  '88% off',
#  '20% off',
#  '85% off',
#  '25% off',
#  '88% off',
#  '66% off',
#  '85% off',
#  '82% off',
#  '32% off',
#  '53% off',
#  '77% off',
#  '33% off',
#  '74% off',
#  '68% off',
#  '26% off',
#  '79% off',
#  '81% off',
#  '55% off',
#  '79% off',
#  '33% off',
#  '83% off',
#  '66% off',
#  '85% off',
#  '70% off',
#  '25% off',
#  '78% off',
#  '72% off',
#  '25% off',
#  '80% off',
#  '70% off',
#  '76% off',
#  '73% off',
#  '29% off',
#  '78% off',
#  '78% off',
#  '25% off',
#  '70% off',
#  '78% off',
#  '81% off',
#  '74% off',
#  '78% off',
#  '26% off',
#  '71% off',
#  '32% off',
#  '76% off',
#  '85% off',
#  '45% off',
#  '85% off',
#  '62% off',
#  '78% off',
#  '66% off',
#  '76% off',
#  '66% off',
#  '32% off',
#  '66% off',
#  '66% off',
#  '25% off',
#  '84% off',
#  '53% off',
#  '88% off',
#  '68% off',
#  '78% off',
#  '68% off',
#  '83% off',
#  '83% off',
#  '83% off',
#  '78% off',
#  '78% off',
#  '78% off',
#  '82% off',
#  '78% off',
#  '33% off',
#  '79% off',
#  '20% off',
#  '55% off',
#  '76% off',
#  '85% off',
#  '25% off',
#  '70% off',
#  '78% off',
#  '68% off',
#  '78% off',
#  '78% off',
#  '74% off',
#  '77% off',
#  '82% off',
#  '84% off',
#  '71% off',
#  '72% off',
#  '74% off',
#  '83% off',
#  '86% off',
#  '66% off',
#  '70% off',
#  '88% off',
#  '66% off',
#  '87% off',
#  '81% off',
#  '25% off',
#  '66% off',
#  '82% off',
#  '30% off',
#  '78% off',
#  '55% off',
#  '68% off',
#  '79% off',
#  '28% off',
#  '53% off',
#  '76% off',
#  '75% off',
#  '84% off',
#  '68% off',
#  '78% off',
#  '71% off',
#  '82% off',
#  '78% off',
#  '80% off',
#  '28% off',
#  '33% off',
#  '70% off',
#  '78% off',
#  '76% off',
#  '79% off',
#  '78% off',
#  '76% off',
#  '81% off',
#  '78% off',
#  '78% off',
#  '78% off']

# %%
#extracting all the product price
product_price=driver.find_elements_by_xpath("//div[@class='_25b18c']//div[1]") #element's' gives us all the elements
product_price
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="27de4b97574a047d08d30edef533e0f2", element
#  '₹664',
#  '₹282',
#  '₹399',
#  '₹599',
#  '₹664',
#  '₹293',
#  '₹559',
#  '₹426',
#  '₹664',
#  '₹1,499',
#  '₹265',
#  '₹569',
#  '₹699',
#  '₹349',
#  '₹311',
#  '₹232',
#  '₹1,009',
#  '₹349',
#  '₹569',
#  '₹170',
#  '₹219',
#  '₹249',
#  '₹639',
#  '₹599',
#  '₹599',
#  '₹210',
#  '₹284',
#  '₹825',
#  '₹426',
#  '₹284',
#  '₹399',
#  '₹426',
#  '₹426',
#  '₹219']

# %%
product_priceonlyonly1=[]
for i in page_url[:3]:
    driver.get(i)
    product_priceonly=driver.find_elements_by_xpath("//div[@class='_25b18c']//div[1]")
    for i in product_priceonly:
        product_priceonlyonly1.append(i.text)
product_priceonlyonly1
# Out:
# ['₹739',
#  '₹549',
#  '₹455',
#  '₹295',
#  '₹669',
#  '₹509',
#  '₹225',
#  '₹599',
#  '₹299',
#  '₹969',
#  '₹299',
#  '₹209',
#  '₹225',
#  '₹949',
#  '₹539',
#  '₹664',
#  '₹210',
#  '₹499',
#  '₹599',
#  '₹699',
#  '₹331',
#  '₹599',
#  '₹225',
#  '₹1,009',
#  '₹246',
#  '₹404',
#  '₹379',
#  '₹664',
#  '₹203',
#  '₹599',
#  '₹210',
#  '₹426',
#  '₹334',
#  '₹969',
#  '₹398',
#  '₹599',
#  '₹426',
#  '₹349',
#  '₹379',
#  '₹219',
#  '₹426',
#  '₹669',
#  '₹203',
#  '₹219',
#  '₹379',
#  '₹204',
#  '₹474',
#  '₹1,479',
#  '₹739',
#  '₹609',
#  '₹295',
#  '₹225',
#  '₹379',
#  '₹224',
#  '₹257',
#  '₹239',
#  '₹664',
#  '₹309',
#  '₹609',
#  '₹516',
#  '₹426',
#  '₹969',
#  '₹239',
#  '₹209',
#  '₹664',
#  '₹474',
#  '₹211',
#  '₹319',
#  '₹799',
#  '₹202',
#  '₹331',
#  '₹349',
#  '₹699',
#  '₹217',
#  '₹269',
#  '₹599',
#  '₹799',
#  '₹249',
#  '₹599',
#  '₹299',
#  '₹1,009',
#  '₹225',
#  '₹669',
#  '₹225',
#  '₹426',
#  '₹474',
#  '₹474',
#  '₹379',
#  '₹204',
#  '₹257',
#  '₹430',
#  '₹303',
#  '₹398',
#  '₹739',
#  '₹255',
#  '₹210',
#  '₹499',
#  '₹379',
#  '₹639',
#  '₹295',
#  '₹282',
#  '₹664',
#  '₹399',
#  '₹599',
#  '₹293',
#  '₹426',
#  '₹559',
#  '₹426',
#  '₹1,499',
#  '₹799',
#  '₹265',
#  '₹569',
#  '₹349',
#  '₹799',
#  '₹311',
#  '₹232',
#  '₹349',
#  '₹1,009',
#  '₹569',
#  '₹170',
#  '₹249',
#  '₹699',
#  '₹639',
#  '₹599',
#  '₹210',
#  '₹664',
#  '₹284',
#  '₹825',
#  '₹599',
#  '₹426',
#  '₹284',
#  '₹399',
#  '₹426',
#  '₹170',
#  '₹265']

# %%
print(len(brand_names1),len(discount_percentageonly1),len(product_priceonlyonly1))
# Out:
# 120 135 135
